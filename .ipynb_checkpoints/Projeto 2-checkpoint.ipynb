# %% [markdown]
# ## PROJETO 2 - ANÁLISE DE DADOS

# %% [markdown]
# ***
#
# >Maria Eduarda Gonçalves Torres
#
# >Pedro Rubens
#
# ***

# %% [markdown]
# <kbd><code style="background:yellow;color:black">Carregando as bibliotecas</code></kbd>

# %%
# %matplotlib inline
import pandas as pd
import statsmodels.api as sm 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import os
import re 
import seaborn as sns
from numpy import nan
from numpy import isnan
import sys 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <kbd><code style="background:yellow;color:black">Importando dataset</code></kbd>

# %%
data='data.csv'
dados = pd.read_csv( data, index_col = 0)
dados.head(5)
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %% [markdown]
#  <kbd><code style="background:yellow;color:black">Entendendo colunas do dataset</code></kbd>

# %% [markdown]
# - <span style="color:brown">*id* -></span></kbd></mark> número de identificação
# - <span style="color:brown">*diagnosis* -></span></kbd></mark> Diagnóstico ( M = maligno, B = benigno )
# - <span style="color:brown">*radius_mean* -></span></kbd></mark> raio ( média das distâncias do centro aos pontos do perímetro )
# - <span style="color:brown">*texture_mean* -></span></kbd></mark> textura ( desvio padrão dos valores da escala de cinza )
# - <span style="color:brown">*perimeter_mean* -> </span></kbd></mark>perímetro
# - <span style="color:brown">*area_mean* -></span></kbd></mark> área
# - <span style="color:brown">*smoothness_mean* -> </span></kbd></mark>suavidade ( variação local nos comprimentos dos raios )
# - <span style="color:brown">*compactness_mean* -> </span></kbd></mark>compactação ( perímetro ^ 2 / área - 1,0 )
# - <span style="color:brown">*concavity_mean* -></span></kbd></mark> concavidade ( severidade das porções côncavas do contorno )
# - <span style="color:brown">*concave points_mean* -></span></kbd></mark> pontos côncavos ( número de porções côncavas do contorno )
# - <span style="color:brown">*symmetry_mean* -></span></kbd></mark> simetria
# - <span style="color:brown">*fractal_dimension_mean* -></span></kbd></mark> dimensão fractal ( "aproximação do litoral" - 1 )

# %% [markdown]
# <kbd><code style="background:yellow;color:black">O que vamos analisar?</code></kbd>
# ***
# >O objetivo do projeto é **explicar / prever**  as chances do câncer de mama do paciente ser *benigno ou maligno*, em
# função das características dos núcleos celulares.
#
# >Os recursos são calculados a partir de uma biópsia aspirativa com agulha fina ( BAAF ) de uma massa mamária. Por
# conta disso, vamos considerar a coluna *diagnosis* como variável dependente ( variável resposta / variável target ) para ser considerada no `eixo y`. E  o resto das colunas como variávies independentes ( variávies explicativas / variávies features ) no `eixo x`.
# ***

# %% [markdown]
# <p/>
#
# <kbd><code style="background:yellow;color:black">Fazendo manipulações no datase</code></kbd>
# ***
# > Durante o semestre estudamos diversos modelos para machine learning e como separamos nosso dataset em duas
# variáveis, uma <mark> qualitativa ( target )</mark> e outra <mark> quantitativa ( features ) </mark>, neste projeto vamos utilizar as técnicas descritas em *Classificadores*, ou seja vamos classificar nossos dados em categorias.
#
# >Trabalhar com variáveis quantitativas e qualitativas não nos trazem uma exploração profunda sobre nossos dados, de modo que teremos que transformar nossa `variável Y` com valores categóricos B e M em valores numéricos, onde teremos <span style="color:blue">*1*</span> para <span style="color:blue">*B*</span> e <span style="color:red">*0*</span> para <span style="color:red">*M*</span>.
#
#
# >Além disso, vamos deletar as colunas com dados faltantes e verificar se `variável X` está em toda em float.
# ***

# %% [markdown]
# * Vamos usar  `df.drop( )`  para remover a última coluna que esta em branco, como não temos o nome da coluna vamos usar `df.drop(df.columns[[ ]], axis=1)`, onde conseguimos apagar a coluna pelo número de sua posição.

# %%
dados = dados.drop(dados.columns[[31]], axis=1) 
dados
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00     1479.0
# 926682           M        20.13         28.25          131.20     1261.0
# 926954           M        16.60         28.08          108.30      858.1
# 927241           M        20.60         29.33          140.10     1265.0
# 92751            B         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %% [markdown]
# * Usamos `df.shape(  )` para descobrir o número de linhas e o número de colunas.

# %%
dados.shape
# Out:
# (569, 31)

# %% [markdown]
# * `df.info()` vai conferir se não temos mais nenhum *Nan* no dataframe e se nossas `variáveis X` estão todas em *float*.

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# * `dados['diagnosis'].map({'B': 1, 'M': 0})` transforma <span style="color:blue">*B $\Rightarrow$ 1*</span> & <span style="color:red">*M $\Rightarrow$ 0*</span>

# %%
dados['diagnosis'] = dados['diagnosis'].map({'B': 1, 'M': 0})
dados.head()
# Out:
#           diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302            0        17.99         10.38          122.80     1001.0
# 842517            0        20.57         17.77          132.90     1326.0
# 84300903          0        19.69         21.25          130.00     1203.0
# 84348301          0        11.42         20.38           77.58      386.1
# 84358402          0        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %% [markdown]
# <kbd><code style="background:yellow;color:black">Análise exploratória</code></kbd>
# ***
# > Agora que já temos todo nosso conjunto de dados em valor numérico, vamos começar as análises.
#
# >Iremos montar um histograma que vai nos ajudar a  entender como sua variável <u>*target*</u> se comporta cruzada com cada <u>*feature*</u> e porque precisamos de todas aquelas colunas para previr se o cancêr do paciente vai ser maligno ou benigno.
#
# > Em razão da variável target ser separada em `0` e `1`  iremos plotar dois histogramas, no qual cada um vai representar o comportamento das features em relação a <span style="color:blue">*B*</span> e <span style="color:red">*M*</span>. Com base nos histogramas, vimos que algumas features não se relacionam com a nossa target, pois suas distribuições nos dois histogramas mostram que independente da doença do paciente ser maligna ou benigna isso não influencia na sua distribuição. E iremos descartar essas variáveis a fim de deixar o nosso modelo mais preciso.
#
#
# >No código abaixo vamos chamar as <u>*features*</u> de `varquanti` e a <u>*target*</u> de `varquali`.
# ***

# %%
varquanti = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
 'smoothness_mean', 'compactness_mean', 'concavity_mean',
 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst',
 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst',
 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

varquali = dados['diagnosis']

# %%
for var in varquanti:
    
    minimo = dados[var].min()  
    maximo = dados[var].max()
    faixas = np.linspace(minimo, maximo, 16)
    bins = faixas   

    plt.figure(figsize=(10,5))

    plt.subplot(121)
    plt.hist(dados[dados.diagnosis==1][var], bins = faixas, color = 'b',density=True)
    plt.xlabel(var)
    plt.ylabel('Beligno')

    plt.subplot(122)
    plt.hist(dados[dados.diagnosis==0][var], bins = faixas, color = 'r',density=True)
    plt.xlabel(var)
    plt.ylabel('Maligno')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# ***
# > Depois de analisarmos resolvemos tirar as features :
# >
# > $\Rightarrow$ `texture_mean`
# >
# > $\Rightarrow$ `smoothness_mean`
# >
# > $\Rightarrow$ `concave points_se`
# >
# > $\Rightarrow$`fractal_dimension_se`
#
# > No entanto, só vamos começar a trabalhar sem essas features pós a aplicação dos modelos de predição.
# ***

# %% [markdown]
# <p/>
#
# <kbd><code style="background:yellow;color:black">Aplicando técnicas escolhidas</code></kbd>
# ***
# > Antes de começarmos a construir e validar nosso modelo, temos que organizar os dados em conjuntos. Para avaliarmos o desempenho dos classificadores temos que separar nosso dataset em <mark>*base de treinamento*</mark> e <mark>*base teste*</mark>. O modelo de treinamento é utilizado para prevermos do conjunto de testes não visualizados, e a base de treinamento vai treinar e avaliar o modelo que escolhemos. Quanto maior a porcentagem de acertos, melhor o modelo escolhido.
# ***

# %%
X = dados.drop('diagnosis',1)
Y = dados.diagnosis.values

# %% [markdown]
# * Como nao temos a escala de todas as colunas, vamos aplicar o `MinMaxScaler()` para fazer a reescala dos dados, evitando problema no treino do nosso modelo

# %%
min_max_scaler = MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# %% [markdown]
# * `train_test_split` vai separar o dataframe em base de treinamento e de teste.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# <mark>*1. <u> Logistic regression</u>*</mark>
# > Nossa primeira tentativa de regressão logistica foi por meio da biblioteca do python Stats Model, mas houveram alguns problemas quando fomos efetuar o seu uso ( a base de treinamento nao rodou ). Com isso tivemos que refazer utilizando outra biblioteca do python(Sklearn) para conseguir os nossos resultados de predição.

# %%
clf = LogisticRegression(random_state=0).fit(X_train, Y_train)
print("Accuracy:",clf.score(X_test, Y_test))
# Out:
# Accuracy: 0.9574468085106383

# %%
X = dados.drop('diagnosis',1)

scaler = StandardScaler()
scaler.fit(X) 
X_scaled = pd.DataFrame(scaler.transform(X),columns = X.columns)

clf = LogisticRegression(random_state = 0)
clf.fit(X_scaled, Y)

feature_importance = abs(clf.coef_[0])
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

featfig = plt.figure(figsize=(10,7))
featax = featfig.add_subplot(1, 1, 1)
featax.barh(pos, feature_importance[sorted_idx], align='center')
featax.set_yticks(pos)
featax.set_yticklabels(np.array(X.columns)[sorted_idx], fontsize=8)
featax.set_xlabel('Relative Feature Importance')

plt.tight_layout()   
plt.show()

# %% [markdown]
# > Plotamos este gráfico para entender melhor quais features foram mais impactantes para a tomada de decisão do classificador.

# %% [markdown]
# <mark>*2. <u>Decision Tree</u>*</mark>

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,Y_train)
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.925531914893617

# %% [markdown]
# <mark>*3. <u>Naive Bayes</u>*</mark>

# %%
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
y_pred = gnb.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.9361702127659575

# %% [markdown]
# <mark>*4. <u>Random Forest</u>*</mark>

# %%
random = RandomForestRegressor()
random.fit(X_train,Y_train)
y_pred_rf = random.predict(X_test)
print("Accuracy:", 1-(np.mean((Y_test - y_pred_rf)**2)))
# Out:
# Accuracy: 0.9640414893617021

# %% [markdown]
# <kbd><code style="background:yellow;color:black">Refazando os calculos </code></kbd>
# ***
# > Para tentarmos aperfeiçoar mais nosso modelo, iremos refazer nossos cálculos sem as features que consideramos irrelevantes, após a análise do histograma.
# ***

# %%
X = dados.drop(columns=['diagnosis','texture_mean','smoothness_mean','fractal_dimension_se','concave points_se'])
X = min_max_scaler.fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# <mark>*1. <u> Logistic regression</u>*</mark>

# %%
clf = LogisticRegression(random_state=0).fit(X_train, Y_train)
print("Accuracy:",clf.score(X_test, Y_test))
# Out:
# Accuracy: 0.9574468085106383

# %% [markdown]
# <mark>*2. <u> Decision Tree</u>*</mark>

# %%
random.fit(X_train,Y_train)
y_pred_rf = random.predict(X_test)
print("Accuracy:",1-(np.mean((Y_test - y_pred_rf)**2)))
# Out:
# Accuracy: 0.9617473404255319

# %% [markdown]
# <mark>*3. <u>Naive Bayes</u>*</mark>

# %%
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
y_pred = gnb.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.9361702127659575

# %% [markdown]
# <mark>*4. <u>Random Forest</u>*</mark>

# %%
random.fit(X_train,Y_train)
y_pred_rf = random.predict(X_test)
print("Accuracy:",1-(np.mean((Y_test - y_pred_rf)**2)))
# Out:
# Accuracy: 0.9653952127659574

# %% [markdown]
# <kbd><code style="background:yellow;color:black">Conclusão</code></kbd>
# ***
# >Concluimos que todos os modelos de classificação aplicados (Regressão logística, Random Forest, Naive Bayes, ou Decision Tree), tiveram uma precisão de mais de 90%, o que é ótimo considerando que nosso objetivo era conseguir prever qual era o tipo de câncer de mama (benigno ou maligno), então já era esperado um nível de precisão alto.
#
# >Temos como o método mais assertivo entre eles, o método Random Forest com uma precisão de 96%. Os cálculos antes e depois de mudarmos o número de features em nosso modelo, não teve uma melhoria significativa nos classificadores, já que as mudanças percentuais foram de menos de 1% na maior parte dos casos, e apenas o Decision Tree teve uma melhora de aproximadamente 4%.
# ***

# %% [markdown]
# <kbd><code style="background:yellow;color:black">Referências</code></kbd>
# ***
# [Dataset](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data)
#
# [*Decision Tree*](https://www.datacamp.com/community/tutorials/decision-tree-classification-python?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=278443377086&utm_targetid=aud-392016246653:dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=1001773&gclid=Cj0KCQiAkuP9BRCkARIsAKGLE8WrlFUBEFvxghBpZuaTaQpIU_lUFfQsQXRPy2U2w41h6NJnRKu9fngaAu7uEALw_wcB)
#
# [*Decision Tree Classifier*](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
#
# [*Random Forests Classifier*](https://www.datacamp.com/community/tutorials/random-forests-classifier-python?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=278443377095&utm_targetid=aud-392016246653:dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=1001773&gclid=CjwKCAiAtej9BRAvEiwA0UAWXnX5lm1T1ji6e6Ki8M7p5FkRfdi-Ra8dnCT_iADnOWr-VnInfCbXcxoCXWgQAvD_BwE)
#
# [*Important features*](https://stackoverflow.com/questions/24255723/sklearn-logistic-regression-important-features?rq=1)
# ***
